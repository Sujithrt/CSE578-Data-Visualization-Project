# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.neural_network import MLPClassifier
# from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import warnings

warnings.filterwarnings("ignore") # to ignore warnings being printed on the console


def get_workclass_value(x):
    if x == "Without-pay":
        return 7
    elif x == "Private":
        return 6
    elif x == "State-gov":
        return 5
    elif x == "Self-emp-not-inc":
        return 4
    elif x == "Local-gov":
        return 3
    elif x == "Federal-gov":
        return 2
    else:
        return 1
    
    
def get_marital_status_value(x):
    if x == "Never-married":
        return 7
    elif x == "Separated":
        return 6
    elif x == "Married-spouse-absent":
        return 5
    elif x == "Widowed":
        return 4
    elif x == "Divorced":
        return 3
    elif x == "Married-civ-spouse":
        return 2
    else:
        return 1


def get_occupation_value(x):
    if x in ["Exec-managerial", "Prof-specialty", "Protective-serv"]:
        return 1
    elif x in ["Sales", "Transport-moving", "Tech-support", "Craft-repair"]:
        return 2
    else:
        return 3


def get_relationship_value(x):
    if x == "Own-child":
        return 6
    elif x == "Other-relative":
        return 5
    elif x == "Unmarried":
        return 4
    elif x == "Not-in-family":
        return 3
    elif x == "Husband":
        return 2
    else:
        return 1


def get_race_value(x):
    if x == "Other":
        return 5
    elif x == "Amer-Indian-Eskimo":
        return 4
    elif x == "Black":
        return 3
    elif x == "White":
        return 2
    else:
        return 1


def get_sex_value(x):
    if x == "Male":
        return 2
    else:
        return 1

    
def get_native_country_value(x):
    if x in ["United-States", "Cuba", "Poland", "Thailand", "Ecuador", "China", "South", "Scotland", "Greece", "Ireland", "Hungary"]:
        return 2
    elif x in ["India", "England", "Canada", "Germany", "Iran", "Philippines", "Cambodia", "Taiwan", "France", "Italy", "Japan", "Yugoslavia", "Hong"]:
        return 1
    else:
        return 3
    

def get_class_value(x):
    if x == ">50K":
        return 1
    else:
        return 0
    

temp_df1 = pd.read_csv("dataset/adult.data.txt", header=None, sep=", ")
temp_df2 = pd.read_csv("dataset/adult.test.txt", header=None, sep=", ")
df = pd.concat([temp_df1, temp_df2]).sample(frac=1)
df.columns = ["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "class"]
df["class"] = df["class"].apply(lambda x: x.replace(".", ""))
df = df[df["workclass"] != '?']
df = df[df["education"] != '?']
df = df[df["marital-status"] != '?']
df = df[df["occupation"] != '?']
df = df[df["relationship"] != '?']
df = df[df["race"] != '?']
df = df[df["sex"] != '?']
df = df[df["native-country"] != '?']

below = df[df["class"] == "<=50K"].sample(n=11208)
above = df[df["class"] == ">50K"]

train_data = pd.concat([above, below]).sample(frac=1)
train_data = train_data.drop("capital-loss", axis=1)
train_data = train_data.drop("education", axis=1)
train_data = train_data.drop("fnlwgt", axis=1)
train_data['workclass'] = train_data['workclass'].apply(get_workclass_value)
train_data['marital-status'] = train_data['marital-status'].apply(get_marital_status_value)
train_data['occupation'] = train_data['occupation'].apply(get_occupation_value)
train_data['relationship'] = train_data['relationship'].apply(get_relationship_value)
train_data['race'] = train_data['race'].apply(get_race_value)
train_data['sex'] = train_data['sex'].apply(get_sex_value)
train_data['native-country'] = train_data['native-country'].apply(get_native_country_value)
train_data['class'] = train_data['class'].apply(get_class_value)
train_data.head()
# Out:
#        age  workclass  education-num  marital-status  occupation  \
# 11727   17          6              7               7           3
# 23681   56          6             10               2           2
# 175     36          6             10               2           1
# 1583    21          6             13               7           2
# 6792    47          2             12               2           3
#
#        relationship  race  sex  capital-gain  hours-per-week  native-country  \
# 11727             6     5    2             0              12               2
# 23681             2     2    2             0              50               2
# 175               2     2    2             0              45               2
# 1583              6     3    1             0              30               2
# 6792              2     2    2             0              40               2
#
#        class
# 11727      0
# 23681      1
# 175        1
# 1583       0
# 6792       1

# %%
feature_matrix_df = train_data.iloc[:, :-1]
labels_df = train_data.iloc[:, -1]
feature_matrix = feature_matrix_df.values
labels = labels_df.values

train_data, test_data, train_labels, test_labels = train_test_split(feature_matrix, labels, test_size=0.2, random_state=42)

transformed_train_data = MinMaxScaler().fit_transform(train_data)
transformed_test_data = MinMaxScaler().fit_transform(test_data)

transformed_train_data[:5,:]
# Out:
# array([[0.15068493, 0.83333333, 0.8       , 0.16666667, 0.5       ,
#         0.2       , 0.25      , 1.        , 0.        , 0.44897959,
#         0.5       ],
#        [0.34246575, 0.5       , 0.6       , 0.16666667, 0.5       ,
#         0.2       , 0.25      , 1.        , 0.        , 0.39795918,
#         1.        ],
#        [0.21917808, 0.83333333, 0.8       , 0.16666667, 1.        ,
#         0.2       , 0.25      , 1.        , 0.        , 0.60204082,
#         0.        ],
#        [0.61643836, 0.83333333, 1.        , 0.16666667, 0.        ,
#         0.2       , 0.25      , 1.        , 1.        , 0.39795918,
#         0.5       ],
#        [0.4109589 , 0.16666667, 0.53333333, 0.16666667, 1.        ,
#         0.2       , 0.25      , 1.        , 0.        , 0.39795918,
#         0.5       ]])

# %%
def train_model(model_name, Model, tuned_parameters, X_train, y_train, fold_num=10, scoring_function="f1_macro",
                useRandomizedSearch=True):
    if useRandomizedSearch == False:
        clf = GridSearchCV(Model, tuned_parameters, cv=fold_num, scoring=scoring_function)
    else:
        clf = RandomizedSearchCV(Model, tuned_parameters, cv=fold_num, scoring=scoring_function)
    clf.fit(X_train, y_train)

    print("Best parameters set found:")
    print(clf.best_params_)
    print("Best score: %0.3f" % clf.best_score_)
    print("Scores on training set:")
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    meanMap = {}
    stdMap = {}
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        meanMap[str(params)] = mean
        stdMap[str(params)] = std
    for params in sorted(meanMap, key=meanMap.get, reverse=True):
        print("%0.3f (+/-%0.03f) for %r" % (meanMap[params], stdMap[params] * 2, params))

    return clf.best_params_

models_dict = {}
print("\n\nTRAINING DATA RESULTS:")
print("\n\nBaggingClassifier Classifier")
tuned_parameters = {'random_state': [10],
                    'n_estimators': np.arange(10, 41, 4),
                    'max_samples': [0.7, 0.8],
                    'max_features': [0.7, 0.8],
                    'oob_score': [True, False]}
models_dict["BaggingClassifier()"] = train_model("BaggingClassifier", BaggingClassifier(),
                                                tuned_parameters, transformed_train_data, train_labels,
                                                useRandomizedSearch=True)

print("\n\nMultinomialNB Classifier")
tuned_parameters = {'fit_prior': [True, False],
                    'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 2]}
models_dict["MultinomialNB()"] = train_model("MultinomialNB", MultinomialNB(), tuned_parameters,
                                             transformed_train_data, train_labels, useRandomizedSearch=True)

print("\n\nLogisticRegression Classifier")
tuned_parameters = {'random_state': [10],
                    'C': [0.01, 0.1, 1, 0.001],
                    'fit_intercept': [True, False],
                    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
                    'warm_start': [True, False]}
models_dict["LogisticRegression()"] = train_model("LogisticRegression", LogisticRegression(), tuned_parameters,
                                                  transformed_train_data, train_labels, useRandomizedSearch=True)

print("\n\nAdaBoostClassifier Classifier")
tuned_parameters = {'random_state': [10],
                    'n_estimators': range(10, 41, 4),
                    'learning_rate': [0.001, 0.01, 0.1, 1],
                    'algorithm': ['SAMME.R', 'SAMME']}
models_dict["AdaBoostClassifier()"] = train_model("AdaBoostClassifier", AdaBoostClassifier(), tuned_parameters,
                                                  transformed_train_data, train_labels, useRandomizedSearch=True)

print("\n\nRandomForestClassifier Classifier")
tuned_parameters = {'random_state': [10],
                    'n_estimators': np.arange(10, 41, 4),
                    'max_depth': [10, 20, 30, 40],
                    'min_samples_split': [2, 3, 5, 10],
                    'warm_start': [True, False],
                    'min_samples_leaf': [1, 2, 4]}
models_dict["RandomForestClassifier()"] = train_model("RandomForestClassifier", RandomForestClassifier(),
                                                      tuned_parameters, transformed_train_data, train_labels,
                                                      useRandomizedSearch=True)

print("\n\nGradientBoostingClassifier Classifier")
tuned_parameters = {'random_state': [10],
                    'n_estimators': range(10, 41, 4),
                    'max_depth': range(3, 8),
                    'min_samples_split': range(2, 5),
                    'min_samples_leaf': range(40, 60, 4),
                    'max_features': range(5, 10),
                    'subsample': [0.6, 0.7, 0.75, 0.8, 0.85, 0.9]}
models_dict["GradientBoostingClassifier()"] = train_model("GradientBoostingClassifier",
                                                          GradientBoostingClassifier(), tuned_parameters,
                                                          transformed_train_data, train_labels,
                                                          useRandomizedSearch=True)
print("\n\nDecisionTreeClassifier Classifier")
tuned_parameters = {'random_state': [10],
                    'max_depth': range(10, 30, 3),
                    'min_samples_split': [2, 5, 10],
                    'min_samples_leaf': [1, 2, 3, 4]}
models_dict["DecisionTreeClassifier()"] = train_model("DecisionTreeClassifier", DecisionTreeClassifier(),
                                                      tuned_parameters, transformed_train_data, train_labels,
                                                      useRandomizedSearch=True)

print("\n\nMLPClassifier Classifier")
tuned_parameters = {'random_state': [10],
                    'max_iter': range(200, 500, 100),
                    'hidden_layer_sizes': [(40, 40, 40), (50, 50, ), (70, 50, 30,), (70, 30,), (30,)],
                    'activation': ['relu', 'identity', 'logistic', 'tanh'],
                    'solver': ['lbfgs', 'sgd', 'adam'],
                    'shuffle': [True, False],
                    'learning_rate_init': [0.001, 0.01, 0.1],
                    'learning_rate': ['constant', 'invscaling', 'adaptive']}
models_dict["MLPClassifier()"] = train_model("MLPClassifier", MLPClassifier(), tuned_parameters,
                                             transformed_train_data, train_labels, useRandomizedSearch=True)

# print("\n\nSVC Classifier")
# tuned_parameters = {'random_state': [10],
#                     'kernel': ['rbf', 'linear', 'poly', 'sigmoid'],
#                     'degree': np.arange(2, 20),
#                     'C': np.arange(1, 10)}
# models_dict["SVC()"] = train_model("SVC", SVC(), tuned_parameters, transformed_train_data, train_labels,
#                                    useRandomizedSearch=True)

print("\n\nKNeighborsClassifier Classifier")
tuned_parameters = {'n_neighbors': np.arange(1, 31),
                    'weights': ["uniform", "distance"],
                    'p': np.arange(1, 6),
                    'metric': ["minkowski", "braycurtis", "canberra", "matching", "dice", "kulsinski",
                               "rogerstanimoto", "russellrao", "sokalmichener", "sokalsneath"]}
models_dict["KNeighborsClassifier()"] = train_model("KNeighborsClassifier", KNeighborsClassifier(),
                                                    tuned_parameters, transformed_train_data, train_labels,
                                                    useRandomizedSearch=True)
# Out:
# TRAINING DATA RESULTS:
#
#
# BaggingClassifier Classifier
# Best parameters set found:
# {'random_state': 10, 'oob_score': True, 'n_estimators': 38, 'max_samples': 0.7, 'max_features': 0.7}
# Best score: 0.824
# Scores on training set:
# 0.824 (+/-0.016) for "{'random_state': 10, 'oob_score': True, 'n_estimators': 38, 'max_samples': 0.7, 'max_features': 0.7}"
# 0.822 (+/-0.018) for "{'random_state': 10, 'oob_score': True, 'n_estimators': 38, 'max_samples': 0.8, 'max_features': 0.8}"
# 0.821 (+/-0.019) for "{'random_state': 10, 'oob_score': True, 'n_estimators': 34, 'max_samples': 0.8, 'max_features': 0.8}"
# 0.820 (+/-0.018) for "{'random_state': 10, 'oob_score': True, 'n_estimators': 34, 'max_samples': 0.7, 'max_features': 0.8}"
# 0.820 (+/-0.016) for "{'random_state': 10, 'oob_score': False, 'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.8}"
# 0.820 (+/-0.017) for "{'random_state': 10, 'oob_score': False, 'n_estimators': 26, 'max_samples': 0.7, 'max_features': 0.7}"
# 0.819 (+/-0.017) for "{'random_state': 10, 'oob_score': False, 'n_estimators': 22, 'max_samples': 0.8, 'max_features': 0.7}"
# 0.818 (+/-0.018) for "{'random_state': 10, 'oob_score': False, 'n_estimators': 26, 'max_samples': 0.8, 'max_features': 0.8}"
# 0.814 (+/-0.017) for "{'random_state': 10, 'oob_score': False, 'n_estimators': 14, 'max_samples': 0.8, 'max_features': 0.8}"
# 0.814 (+/-0.017) for "{'random_state': 10, 'oob_score': True, 'n_estimators': 14, 'max_samples': 0.8, 'max_features': 0.8}"
#
#
# MultinomialNB Classifier
# Best parameters set found:
# {'fit_prior': True, 'alpha': 0.1}
# Best score: 0.782
# Scores on training set:
# 0.782 (+/-0.013) for "{'fit_prior': True, 'alpha': 0.1}"
# 0.782 (+/-0.013) for "{'fit_prior': True, 'alpha': 0.0001}"
# 0.782 (+/-0.013) for "{'fit_prior': True, 'alpha': 0.001}"
# 0.782 (+/-0.013) for "{'fit_prior': True, 'alpha': 0.01}"
# 0.781 (+/-0.011) for "{'fit_prior': False, 'alpha': 0.001}"
# 0.781 (+/-0.011) for "{'fit_prior': False, 'alpha': 0.0001}"
# 0.781 (+/-0.014) for "{'fit_prior': True, 'alpha': 2}"
# 0.781 (+/-0.011) for "{'fit_prior': False, 'alpha': 0.1}"
# 0.781 (+/-0.011) for "{'fit_prior': False, 'alpha': 1}"
# 0.781 (+/-0.011) for "{'fit_prior': False, 'alpha': 2}"
#
#
# LogisticRegression Classifier
# Best parameters set found:
# {'warm_start': False, 'solver': 'liblinear', 'random_state': 10, 'fit_intercept': False, 'C': 1}
# Best score: 0.804
# Scores on training set:
# 0.804 (+/-0.019) for "{'warm_start': False, 'solver': 'liblinear', 'random_state': 10, 'fit_intercept': False, 'C': 1}"
# 0.804 (+/-0.019) for "{'warm_start': True, 'solver': 'sag', 'random_state': 10, 'fit_intercept': False, 'C': 1}"
# 0.800 (+/-0.019) for "{'warm_start': True, 'solver': 'newton-cg', 'random_state': 10, 'fit_intercept': True, 'C': 0.1}"
# 0.783 (+/-0.019) for "{'warm_start': False, 'solver': 'lbfgs', 'random_state': 10, 'fit_intercept': False, 'C': 0.01}"
# 0.783 (+/-0.019) for "{'warm_start': False, 'solver': 'sag', 'random_state': 10, 'fit_intercept': False, 'C': 0.01}"
# 0.773 (+/-0.012) for "{'warm_start': True, 'solver': 'lbfgs', 'random_state': 10, 'fit_intercept': False, 'C': 0.001}"
# 0.773 (+/-0.013) for "{'warm_start': False, 'solver': 'newton-cg', 'random_state': 10, 'fit_intercept': False, 'C': 0.001}"
# 0.773 (+/-0.013) for "{'warm_start': True, 'solver': 'liblinear', 'random_state': 10, 'fit_intercept': True, 'C': 0.001}"
# 0.769 (+/-0.015) for "{'warm_start': False, 'solver': 'sag', 'random_state': 10, 'fit_intercept': True, 'C': 0.001}"
# 0.769 (+/-0.015) for "{'warm_start': False, 'solver': 'lbfgs', 'random_state': 10, 'fit_intercept': True, 'C': 0.001}"
#
#
# AdaBoostClassifier Classifier
# Best parameters set found:
# {'random_state': 10, 'n_estimators': 30, 'learning_rate': 1, 'algorithm': 'SAMME'}
# Best score: 0.806
# Scores on training set:
# 0.806 (+/-0.017) for "{'random_state': 10, 'n_estimators': 30, 'learning_rate': 1, 'algorithm': 'SAMME'}"
# 0.804 (+/-0.017) for "{'random_state': 10, 'n_estimators': 26, 'learning_rate': 1, 'algorithm': 'SAMME'}"
# 0.785 (+/-0.015) for "{'random_state': 10, 'n_estimators': 18, 'learning_rate': 0.1, 'algorithm': 'SAMME.R'}"
# 0.764 (+/-0.018) for "{'random_state': 10, 'n_estimators': 22, 'learning_rate': 0.1, 'algorithm': 'SAMME'}"
# 0.760 (+/-0.012) for "{'random_state': 10, 'n_estimators': 18, 'learning_rate': 0.1, 'algorithm': 'SAMME'}"
# 0.760 (+/-0.012) for "{'random_state': 10, 'n_estimators': 26, 'learning_rate': 0.001, 'algorithm': 'SAMME'}"
# 0.760 (+/-0.012) for "{'random_state': 10, 'n_estimators': 10, 'learning_rate': 0.01, 'algorithm': 'SAMME'}"
# 0.760 (+/-0.012) for "{'random_state': 10, 'n_estimators': 18, 'learning_rate': 0.001, 'algorithm': 'SAMME'}"
# 0.760 (+/-0.012) for "{'random_state': 10, 'n_estimators': 30, 'learning_rate': 0.01, 'algorithm': 'SAMME'}"
# 0.760 (+/-0.012) for "{'random_state': 10, 'n_estimators': 34, 'learning_rate': 0.001, 'algorithm': 'SAMME.R'}"
#
#
# RandomForestClassifier Classifier
# Best parameters set found:
# {'warm_start': True, 'random_state': 10, 'n_estimators': 18, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_depth': 10}
# Best score: 0.824
# Scores on training set:
# 0.824 (+/-0.017) for "{'warm_start': True, 'random_state': 10, 'n_estimators': 18, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_depth': 10}"
# 0.824 (+/-0.017) for "{'warm_start': False, 'random_state': 10, 'n_estimators': 34, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 30}"
# 0.824 (+/-0.014) for "{'warm_start': False, 'random_state': 10, 'n_estimators': 22, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 10}"
# 0.824 (+/-0.015) for "{'warm_start': False, 'random_state': 10, 'n_estimators': 30, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_depth': 40}"
# 0.822 (+/-0.018) for "{'warm_start': True, 'random_state': 10, 'n_estimators': 10, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': 40}"
# 0.816 (+/-0.017) for "{'warm_start': True, 'random_state': 10, 'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 40}"
# 0.813 (+/-0.023) for "{'warm_start': False, 'random_state': 10, 'n_estimators': 26, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 40}"
# 0.810 (+/-0.021) for "{'warm_start': False, 'random_state': 10, 'n_estimators': 10, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 30}"
# 0.805 (+/-0.018) for "{'warm_start': True, 'random_state': 10, 'n_estimators': 18, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_depth': 40}"
# 0.803 (+/-0.018) for "{'warm_start': False, 'random_state': 10, 'n_estimators': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_depth': 30}"
#
#
# GradientBoostingClassifier Classifier
# Best parameters set found:
# {'subsample': 0.8, 'random_state': 10, 'n_estimators': 26, 'min_samples_split': 2, 'min_samples_leaf': 44, 'max_features': 8, 'max_depth': 7}
# Best score: 0.826
# Scores on training set:
# 0.826 (+/-0.018) for "{'subsample': 0.8, 'random_state': 10, 'n_estimators': 26, 'min_samples_split': 2, 'min_samples_leaf': 44, 'max_features': 8, 'max_depth': 7}"
# 0.826 (+/-0.020) for "{'subsample': 0.6, 'random_state': 10, 'n_estimators': 26, 'min_samples_split': 4, 'min_samples_leaf': 40, 'max_features': 6, 'max_depth': 7}"
# 0.825 (+/-0.020) for "{'subsample': 0.8, 'random_state': 10, 'n_estimators': 38, 'min_samples_split': 4, 'min_samples_leaf': 48, 'max_features': 8, 'max_depth': 4}"
# 0.824 (+/-0.017) for "{'subsample': 0.7, 'random_state': 10, 'n_estimators': 26, 'min_samples_split': 4, 'min_samples_leaf': 52, 'max_features': 9, 'max_depth': 7}"
# 0.820 (+/-0.015) for "{'subsample': 0.9, 'random_state': 10, 'n_estimators': 30, 'min_samples_split': 2, 'min_samples_leaf': 44, 'max_features': 8, 'max_depth': 3}"
# 0.820 (+/-0.016) for "{'subsample': 0.85, 'random_state': 10, 'n_estimators': 14, 'min_samples_split': 4, 'min_samples_leaf': 44, 'max_features': 8, 'max_depth': 6}"
# 0.818 (+/-0.017) for "{'subsample': 0.7, 'random_state': 10, 'n_estimators': 18, 'min_samples_split': 3, 'min_samples_leaf': 40, 'max_features': 6, 'max_depth': 4}"
# 0.815 (+/-0.017) for "{'subsample': 0.6, 'random_state': 10, 'n_estimators': 14, 'min_samples_split': 2, 'min_samples_leaf': 40, 'max_features': 6, 'max_depth': 4}"
# 0.811 (+/-0.014) for "{'subsample': 0.85, 'random_state': 10, 'n_estimators': 10, 'min_samples_split': 3, 'min_samples_leaf': 52, 'max_features': 8, 'max_depth': 4}"
# 0.809 (+/-0.018) for "{'subsample': 0.6, 'random_state': 10, 'n_estimators': 14, 'min_samples_split': 3, 'min_samples_leaf': 48, 'max_features': 9, 'max_depth': 3}"
#
#
# DecisionTreeClassifier Classifier
# Best parameters set found:
# {'random_state': 10, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 10}
# Best score: 0.812
# Scores on training set:
# 0.812 (+/-0.015) for "{'random_state': 10, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 10}"
# 0.806 (+/-0.011) for "{'random_state': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 13}"
# 0.805 (+/-0.011) for "{'random_state': 10, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 13}"
# 0.803 (+/-0.012) for "{'random_state': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 13}"
# 0.793 (+/-0.017) for "{'random_state': 10, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_depth': 19}"
# 0.792 (+/-0.017) for "{'random_state': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 19}"
# 0.787 (+/-0.022) for "{'random_state': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 22}"
# 0.786 (+/-0.015) for "{'random_state': 10, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_depth': 25}"
# 0.778 (+/-0.018) for "{'random_state': 10, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 22}"
# 0.773 (+/-0.017) for "{'random_state': 10, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 28}"
#
#
# MLPClassifier Classifier
# Best parameters set found:
# {'solver': 'sgd', 'shuffle': True, 'random_state': 10, 'max_iter': 300, 'learning_rate_init': 0.01, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (40, 40, 40), 'activation': 'relu'}
# Best score: 0.822
# Scores on training set:
# 0.822 (+/-0.019) for "{'solver': 'sgd', 'shuffle': True, 'random_state': 10, 'max_iter': 300, 'learning_rate_init': 0.01, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (40, 40, 40), 'activation': 'relu'}"
# 0.822 (+/-0.018) for "{'solver': 'lbfgs', 'shuffle': False, 'random_state': 10, 'max_iter': 300, 'learning_rate_init': 0.01, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (70, 30), 'activation': 'logistic'}"
# 0.817 (+/-0.022) for "{'solver': 'lbfgs', 'shuffle': True, 'random_state': 10, 'max_iter': 200, 'learning_rate_init': 0.001, 'learning_rate': 'invscaling', 'hidden_layer_sizes': (40, 40, 40), 'activation': 'logistic'}"
# 0.815 (+/-0.019) for "{'solver': 'adam', 'shuffle': True, 'random_state': 10, 'max_iter': 400, 'learning_rate_init': 0.1, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (40, 40, 40), 'activation': 'relu'}"
# 0.815 (+/-0.026) for "{'solver': 'adam', 'shuffle': False, 'random_state': 10, 'max_iter': 400, 'learning_rate_init': 0.1, 'learning_rate': 'invscaling', 'hidden_layer_sizes': (70, 50, 30), 'activation': 'relu'}"
# 0.810 (+/-0.020) for "{'solver': 'sgd', 'shuffle': True, 'random_state': 10, 'max_iter': 400, 'learning_rate_init': 0.01, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (50, 50), 'activation': 'logistic'}"
# 0.809 (+/-0.019) for "{'solver': 'sgd', 'shuffle': True, 'random_state': 10, 'max_iter': 300, 'learning_rate_init': 0.1, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (30,), 'activation': 'identity'}"
# 0.809 (+/-0.018) for "{'solver': 'adam', 'shuffle': False, 'random_state': 10, 'max_iter': 400, 'learning_rate_init': 0.001, 'learning_rate': 'constant', 'hidden_layer_sizes': (30,), 'activation': 'logistic'}"
# 0.806 (+/-0.021) for "{'solver': 'adam', 'shuffle': False, 'random_state': 10, 'max_iter': 300, 'learning_rate_init': 0.001, 'learning_rate': 'constant', 'hidden_layer_sizes': (70, 30), 'activation': 'identity'}"
# 0.800 (+/-0.018) for "{'solver': 'sgd', 'shuffle': False, 'random_state': 10, 'max_iter': 400, 'learning_rate_init': 0.1, 'learning_rate': 'invscaling', 'hidden_layer_sizes': (50, 50), 'activation': 'relu'}"
#
#
# KNeighborsClassifier Classifier
# Best parameters set found:
# {'weights': 'uniform', 'p': 3, 'n_neighbors': 16, 'metric': 'canberra'}
# Best score: 0.810
# Scores on training set:
# nan (+/-nan) for "{'weights': 'distance', 'p': 4, 'n_neighbors': 4, 'metric': 'kulsinski'}"
# 0.810 (+/-0.020) for "{'weights': 'uniform', 'p': 3, 'n_neighbors': 16, 'metric': 'canberra'}"
# 0.793 (+/-0.021) for "{'weights': 'distance', 'p': 3, 'n_neighbors': 6, 'metric': 'canberra'}"
# 0.748 (+/-0.019) for "{'weights': 'uniform', 'p': 1, 'n_neighbors': 2, 'metric': 'canberra'}"
# 0.689 (+/-0.062) for "{'weights': 'distance', 'p': 4, 'n_neighbors': 4, 'metric': 'sokalsneath'}"
# 0.673 (+/-0.085) for "{'weights': 'distance', 'p': 1, 'n_neighbors': 6, 'metric': 'sokalsneath'}"
# 0.658 (+/-0.098) for "{'weights': 'distance', 'p': 3, 'n_neighbors': 13, 'metric': 'sokalmichener'}"
# 0.619 (+/-0.016) for "{'weights': 'distance', 'p': 1, 'n_neighbors': 25, 'metric': 'sokalmichener'}"
# 0.619 (+/-0.016) for "{'weights': 'distance', 'p': 3, 'n_neighbors': 28, 'metric': 'rogerstanimoto'}"
# 0.617 (+/-0.015) for "{'weights': 'uniform', 'p': 5, 'n_neighbors': 19, 'metric': 'rogerstanimoto'}"

# %%
def run_model(name, model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    return accuracy_score(y_test, y_predict), f1_score(y_test, y_predict), precision_score(y_test,
                                                                                           y_predict), recall_score(
        y_test, y_predict)


def run_test(models_dict, X_train, X_test, y_train, y_test):
    print("Acc\tF1\tPrec\tRecall\tModel")
    for name in models_dict.keys():
        model = eval(name)
        model.set_params(**models_dict[name])
        acc, f1, prec, rec = run_model(name, model, X_train, X_test, y_train, y_test)
        print("%.4f\t%.4f\t%.4f\t%.4f\t%s" % (acc, f1, prec, rec, name))
        
print("\n\n\nTESTING DATA RESULTS:\n\n")
run_test(models_dict, transformed_train_data, transformed_test_data, train_labels, test_labels)
# Out:
# TESTING DATA RESULTS:
#
#
# Acc	F1	Prec	Recall	Model
# 0.8185	0.8255	0.7848	0.8707	BaggingClassifier()
# 0.7754	0.7888	0.7356	0.8504	MultinomialNB()
# 0.8042	0.8124	0.7703	0.8594	LogisticRegression()
# 0.8035	0.8054	0.7875	0.8241	AdaBoostClassifier()
# 0.8211	0.8294	0.7831	0.8816	RandomForestClassifier()
# 0.8252	0.8320	0.7907	0.8779	GradientBoostingClassifier()
# 0.8069	0.8088	0.7903	0.8282	DecisionTreeClassifier()
# 0.8234	0.8281	0.7966	0.8621	MLPClassifier()
# 0.8066	0.8102	0.7856	0.8363	KNeighborsClassifier()
